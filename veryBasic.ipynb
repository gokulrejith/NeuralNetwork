# %%
inputs = [1,2,3]
weights = [0.2,0.8,-0.5]
bias = 2
output = inputs[0]*weights[0]+inputs[1]*weights[1]+inputs[2]*weights[2]+bias
print(output)
#Just one neuron
# Out:
# 2.3

# %%
from IPython.display import Image
Image(filename = "exp1.png", width=900, height=300)

# %%
inputs = [1,2,3,2.5]
weights = [0.2,0.8,-0.5,1.0]
bias = 2
output = inputs[0]*weights[0]+inputs[1]*weights[1]+inputs[2]*weights[2]+inputs[3]*weights[3]+bias
print(output)
# Out:
# 4.8

# %%
Image(filename = "ex2.png", width=900, height=300)

# %% [markdown]
# # Coding a layer

# %%
inputs = [1,2,3,2.5]

weights1 = [0.2,0.8,-0.5,1.0]
weights2 = [0.5,-0.91,0.26,-0.5]
weights3 = [-0.26,-0.27,0.17,0.87]

bias1 = 2
bias2 = 3
bias3 = 0.5

output = [inputs[0]*weights1[0]+inputs[1]*weights1[1]+inputs[2]*weights1[2]+inputs[3]*weights1[3]+bias1,
         inputs[0]*weights2[0]+inputs[1]*weights2[1]+inputs[2]*weights2[2]+inputs[3]*weights2[3]+bias2,
         inputs[0]*weights3[0]+inputs[1]*weights3[1]+inputs[2]*weights3[2]+inputs[3]*weights3[3]+bias3]
print(output)
# Out:
# [4.8, 1.21, 2.385]

# %%
Image(filename = "ex3.png", width=900, height=300)

# %% [markdown]
# # The dot product

# %% [markdown]
# Combined all the weights and biases into a single list

# %%
inputs = [1,2,3,2.5]

weights = [[0.2,0.8,-0.5,1.0],[0.5,-0.91,0.26,-0.5],[-0.26,-0.27,0.17,0.87]]

biases = [2,3,0.5]

output = [inputs[0]*weights1[0]+inputs[1]*weights1[1]+inputs[2]*weights1[2]+inputs[3]*weights1[3]+bias1,
         inputs[0]*weights2[0]+inputs[1]*weights2[1]+inputs[2]*weights2[2]+inputs[3]*weights2[3]+bias2,
         inputs[0]*weights3[0]+inputs[1]*weights3[1]+inputs[2]*weights3[2]+inputs[3]*weights3[3]+bias3]

layer_outputs = [] #output of current layer
for neuron_weights, neuron_bias in zip(weights, biases):
    neuron_output = 0  #output of given neuron
    for n_input, weight in zip(inputs, neuron_weights):
        neuron_output += n_input*weight
        neuron_output += neuron_bias
        layer_outputs.append(neuron_output)
        
    print(layer_outputs)
#CHECK
# Out:
# [2.2, 5.800000000000001, 6.300000000000001, 10.8]
# [2.2, 5.800000000000001, 6.300000000000001, 10.8, 3.5, 4.68, 8.46, 10.21]
# [2.2, 5.800000000000001, 6.300000000000001, 10.8, 3.5, 4.68, 8.46, 10.21, 0.24, 0.19999999999999996, 1.21, 3.885]

# %%
import numpy as np

# %%
inputs = [1,2,3,2.5]
weights = [[0.2,0.8,-0.5,1.0],[0.5,-0.91,0.26,-0.5],[-0.26,-0.27,0.17,0.87]]
bias = [2 , 3 , 0.5]

# %%
output = np.dot(weights, inputs) + bias
print(output)
# Out:
# [4.8   1.21  2.385]

# %%
weights #3 rows and 4 columns
# Out:
# [[0.2, 0.8, -0.5, 1.0], [0.5, -0.91, 0.26, -0.5], [-0.26, -0.27, 0.17, 0.87]]

# %% [markdown]
# # Batches, Layers and objects

# %%
inputs = [[1, 2, 3, 2.5],[2.0, 5.0, -1.0, 2.0],[-1.5,2.7,3.3,-0.8]]
weights = [[0.2,0.8,-0.5,1.0],
           [0.5,-0.91,0.26,-0.5],
           [-0.26,-0.27,0.17,0.87]]
biases = [2 , 3 , 0.5]

output = np.dot(inputs, np.array(weights).T) + biases
print(output)
# Out:
# [[ 4.8    1.21   2.385]
#  [ 8.9   -1.81   0.2  ]
#  [ 1.41   1.051  0.026]]

# %%
inputs = [[1, 2, 3, 2.5],
          [2.0, 5.0, -1.0, 2.0],
          [-1.5,2.7,3.3,-0.8]]
weights = [[0.2,0.8,-0.5,1.0],
           [0.5,-0.91,0.26,-0.5],
           [-0.26,-0.27,0.17,0.87]]
biases = [2 , 3 , 0.5]

weights2 = [[0.1, -0.14, 0.5],
           [-0.5, 0.12, -0.33],
           [-0.44, 0.73, -0.13]]

biases2 = [-1, 2, -0.5]

layer1_outputs = np.dot(inputs, np.array(weights).T) + biases
layer2_outputs = np.dot(layer1_outputs, np.array(weights2).T) + biases2
print(layer2_outputs)
# Out:
# [[ 0.5031  -1.04185 -2.03875]
#  [ 0.2434  -2.7332  -5.7633 ]
#  [-0.99314  1.41254 -0.35655]]

# %%
X = [[1, 2, 3, 2.5],
     [2.0, 5.0, -1.0, 2.0],
     [-1.5,2.7,3.3,-0.8]]

np.random.seed(0)

class Layer_Dense:
    def__init__(self):
        self.weights = np.random.randn()
    def__forward(self):
        pass
